# %%
import os
import re
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from skimage.filters import sobel, gaussian
from skimage.feature import canny

# %%
# ---------------------------
# Config
# ---------------------------
input_dir  = "figs/projections/chest/projections"
output_dir = "figs/projections/chest/mask_edge"
os.makedirs(output_dir, exist_ok=True)

# 掩码模式：
#   'edge' 使用边缘检测；'threshold' 区间阈值；'extreme' 屏蔽极值(0/255)
MASK_MODE   = "edge"

# 当使用 'threshold'/'extreme' 时的参数
LOW_RATIO   = 0.00
HIGH_RATIO  = 0.95

# 当使用 'edge' 时的参数
EDGE_METHOD = "sobel"   # 'sobel' or 'canny'
EDGE_PCT    = 90.0      # sobel 阈值：百分位
EDGE_SIGMA  = 1.0       # sobel 前的高斯平滑

# canny 的可选参数
CANNY_SIGMA = 1.2
CANNY_LOW   = 0.1
CANNY_HIGH  = 0.3

# %%
# ---------------------------
# Utilities
# ---------------------------
def to_uint8_gray(img):
    """统一转灰度 uint8"""
    arr = img
    if arr.ndim == 3 and arr.shape[2] == 4:  # RGBA -> RGB
        arr = arr[:, :, :3]
    if arr.ndim == 3 and arr.shape[2] == 3:
        if np.issubdtype(arr.dtype, np.floating):
            gray = arr.mean(axis=2)           # [0,1]
            gray = np.clip(gray * 255.0, 0, 255).astype(np.uint8)
        else:
            gray = arr.mean(axis=2).round().astype(np.uint8)
    elif arr.ndim == 2:
        if np.issubdtype(arr.dtype, np.floating):
            gray = np.clip(arr * 255.0, 0, 255).astype(np.uint8)
        else:
            gray = arr.astype(np.uint8)
    else:
        raise ValueError(f"Unsupported image shape: {arr.shape}")
    return gray

def build_initial_mask(gray, mode="threshold", low_ratio=0.00, high_ratio=0.95):
    """
    基础掩码：
    - mode="threshold": 仅保留 [low_ratio, high_ratio] 的像素为 1（其余 0）
    - mode="extreme":   将灰度==0 或 255 的像素置 0，其余 1
    - mode="edge":      使用边缘检测（委托给 build_edge_mask）
    """
    if mode == "threshold":
        low  = int(255 * low_ratio)
        high = int(255 * high_ratio)
        mask = np.where((gray >= low) & (gray <= high), 1, 0).astype(np.uint8)
        return mask
    elif mode == "extreme":
        mask = np.where((gray == 0) | (gray == 255), 0, 1).astype(np.uint8)
        return mask
    elif mode == "edge":
        # 使用全局 EDGE_* 配置
        return build_edge_mask(
            gray=gray,
            method=EDGE_METHOD,
            gaussian_sigma=EDGE_SIGMA,
            thresh_mode="percentile",
            thresh_value=EDGE_PCT,
            canny_sigma=CANNY_SIGMA,
            canny_low=CANNY_LOW,
            canny_high=CANNY_HIGH
        )
    else:
        raise ValueError("mode must be 'threshold' or 'extreme' or 'edge'")

def build_edge_mask(
    gray: np.ndarray,
    method: str = "sobel",        # 'sobel' 或 'canny'
    gaussian_sigma: float = 1.0,  # 边缘前平滑，减少噪声
    thresh_mode: str = "percentile",
    thresh_value: float = 90.0,   # 当 thresh_mode='percentile' 时，使用该百分位 [0,100]
    canny_sigma: float = 1.2,     # 仅对 method='canny'
    canny_low: float = 0.1,       # 仅对 method='canny'，低阈值(0~1)
    canny_high: float = 0.3       # 仅对 method='canny'，高阈值(0~1)
) -> np.ndarray:
    """用边缘检测生成二值 mask，返回 uint8(0/1)"""
    g = gray.astype(np.float32) / 255.0

    if method.lower() == "sobel":
        if gaussian_sigma and gaussian_sigma > 0:
            g = gaussian(g, sigma=gaussian_sigma, preserve_range=True)
        edge_mag = sobel(g)
        if thresh_mode == "percentile":
            t = np.percentile(edge_mag, thresh_value)
            mask = (edge_mag >= t).astype(np.uint8)
        elif thresh_mode == "value":
            t = float(thresh_value)  # 直接使用 [0,1] 阈值
            mask = (edge_mag >= t).astype(np.uint8)
        else:
            raise ValueError("thresh_mode must be 'percentile' or 'value'.")

    elif method.lower() == "canny":
        edges_bool = canny(g, sigma=canny_sigma, low_threshold=canny_low, high_threshold=canny_high)
        mask = edges_bool.astype(np.uint8)
    else:
        raise ValueError("method must be 'sobel' or 'canny'.")

    return 1 - mask

def angle_from_filename(path):
    """从 'deg_XXX.png' 中解析角度整数"""
    m = re.search(r"deg_(\d+)\.png$", os.path.basename(path))
    if not m:
        raise ValueError(f"Bad filename: {path}")
    return int(m.group(1)) % 360



# ---------------------------
# Collect files by angle
# ---------------------------
paths = glob.glob(os.path.join(input_dir, "deg_*.png"))
by_angle = {}
for p in paths:
    ang = angle_from_filename(p)
    by_angle[ang] = p

# ---------------------------
# Process pairs (ang, ang+180)
# ---------------------------

mask_rates = []

visited = set()

for ang in sorted(by_angle.keys()):
    if ang in visited:
        continue
    mate = (ang + 180) % 360
    if mate not in by_angle:
        print(f"Skip angle {ang}: pair {mate} not found.")
        continue

    # 读取两张图
    img_a = plt.imread(by_angle[ang])
    img_b = plt.imread(by_angle[mate])
    gray_a = to_uint8_gray(img_a)
    gray_b = to_uint8_gray(img_b)

    # 生成初始 mask（根据 MASK_MODE 自动选择阈值/极值/边缘）
    mask_a0 = build_initial_mask(gray_a, mode=MASK_MODE, low_ratio=LOW_RATIO, high_ratio=HIGH_RATIO)
    mask_b0 = build_initial_mask(gray_b, mode=MASK_MODE, low_ratio=LOW_RATIO, high_ratio=HIGH_RATIO)

    # +180° 的初始 mask 水平翻转，对齐到 θ 的坐标系
    mask_b0_aligned = np.fliplr(mask_b0)

    # 并集（同一有效像素区域）
    union_mask_theta = (mask_a0 | mask_b0_aligned).astype(np.uint8)

    # 保存：θ 用 θ 坐标的并集；θ+180° 用“翻回去”的并集（保持各自原生坐标）
    out_a = os.path.join(output_dir, os.path.splitext(os.path.basename(by_angle[ang]))[0]   + ".csv")
    out_b = os.path.join(output_dir, os.path.splitext(os.path.basename(by_angle[mate]))[0] + ".csv")

    pd.DataFrame(union_mask_theta).to_csv(out_a, index=False, header=False)
    pd.DataFrame(np.fliplr(union_mask_theta)).to_csv(out_b, index=False, header=False)

    kept = int(union_mask_theta.sum())
    total = union_mask_theta.size
    print(f"[{ang:03d} & {mate:03d}] kept {kept}/{total} ({kept/total:.2%}) -> {out_a}, {out_b}")

    mask_rates.append({
    "angle": ang,
    "mate": mate,
    "kept": kept,
    "total": total,
    "mask_rate": kept / total
    })

    visited.add(ang)
    visited.add(mate)

df_rates = pd.DataFrame(mask_rates)
out_summary = os.path.join(output_dir, "mask_rates_summary.csv")
df_rates.to_csv(out_summary, index=False)

avg_rate = df_rates["mask_rate"].mean()

print("✅ Pairwise-union masks (with +180° flip alignment) generated for all available angle pairs, using edge-based masking if configured.")
print(f"\n📊 average mask rate: {1-avg_rate:.2%} (save to {out_summary})")
# Out:
# [000 & 180] kept 62753/65536 (95.75%) -> figs/projections/chest/mask_edge/deg_00.csv, figs/projections/chest/mask_edge/deg_180.csv
# [003 & 183] kept 62694/65536 (95.66%) -> figs/projections/chest/mask_edge/deg_03.csv, figs/projections/chest/mask_edge/deg_183.csv
# [006 & 186] kept 63328/65536 (96.63%) -> figs/projections/chest/mask_edge/deg_06.csv, figs/projections/chest/mask_edge/deg_186.csv
# [009 & 189] kept 64314/65536 (98.14%) -> figs/projections/chest/mask_edge/deg_09.csv, figs/projections/chest/mask_edge/deg_189.csv
# [012 & 192] kept 64477/65536 (98.38%) -> figs/projections/chest/mask_edge/deg_12.csv, figs/projections/chest/mask_edge/deg_192.csv
# [015 & 195] kept 64706/65536 (98.73%) -> figs/projections/chest/mask_edge/deg_15.csv, figs/projections/chest/mask_edge/deg_195.csv
# [018 & 198] kept 65045/65536 (99.25%) -> figs/projections/chest/mask_edge/deg_18.csv, figs/projections/chest/mask_edge/deg_198.csv
# [021 & 201] kept 65144/65536 (99.40%) -> figs/projections/chest/mask_edge/deg_21.csv, figs/projections/chest/mask_edge/deg_201.csv
# [024 & 204] kept 65105/65536 (99.34%) -> figs/projections/chest/mask_edge/deg_24.csv, figs/projections/chest/mask_edge/deg_204.csv
# [027 & 207] kept 65051/65536 (99.26%) -> figs/projections/chest/mask_edge/deg_27.csv, figs/projections/chest/mask_edge/deg_207.csv
# [030 & 210] kept 64727/65536 (98.77%) -> figs/projections/chest/mask_edge/deg_30.csv, figs/projections/chest/mask_edge/deg_210.csv
# [033 & 213] kept 64667/65536 (98.67%) -> figs/projections/chest/mask_edge/deg_33.csv, figs/projections/chest/mask_edge/deg_213.csv
# [036 & 216] kept 64710/65536 (98.74%) -> figs/projections/chest/mask_edge/deg_36.csv, figs/projections/chest/mask_edge/deg_216.csv
# [039 & 219] kept 64652/65536 (98.65%) -> figs/projections/chest/mask_edge/deg_39.csv, figs/projections/chest/mask_edge/deg_219.csv
# [042 & 222] kept 64480/65536 (98.39%) -> figs/projections/chest/mask_edge/deg_42.csv, figs/projections/chest/mask_edge/deg_222.csv
# [045 & 225] kept 64457/65536 (98.35%) -> figs/projections/chest/mask_edge/deg_45.csv, figs/projections/chest/mask_edge/deg_225.csv
# [048 & 228] kept 64404/65536 (98.27%) -> figs/projections/chest/mask_edge/deg_48.csv, figs/projections/chest/mask_edge/deg_228.csv
# [051 & 231] kept 64453/65536 (98.35%) -> figs/projections/chest/mask_edge/deg_51.csv, figs/projections/chest/mask_edge/deg_231.csv
# [054 & 234] kept 64550/65536 (98.50%) -> figs/projections/chest/mask_edge/deg_54.csv, figs/projections/chest/mask_edge/deg_234.csv
# [057 & 237] kept 64586/65536 (98.55%) -> figs/projections/chest/mask_edge/deg_57.csv, figs/projections/chest/mask_edge/deg_237.csv
# [060 & 240] kept 64625/65536 (98.61%) -> figs/projections/chest/mask_edge/deg_60.csv, figs/projections/chest/mask_edge/deg_240.csv
# [063 & 243] kept 64476/65536 (98.38%) -> figs/projections/chest/mask_edge/deg_63.csv, figs/projections/chest/mask_edge/deg_243.csv
# [066 & 246] kept 64097/65536 (97.80%) -> figs/projections/chest/mask_edge/deg_66.csv, figs/projections/chest/mask_edge/deg_246.csv
# [069 & 249] kept 64063/65536 (97.75%) -> figs/projections/chest/mask_edge/deg_69.csv, figs/projections/chest/mask_edge/deg_249.csv
# [072 & 252] kept 63946/65536 (97.57%) -> figs/projections/chest/mask_edge/deg_72.csv, figs/projections/chest/mask_edge/deg_252.csv
# [075 & 255] kept 63727/65536 (97.24%) -> figs/projections/chest/mask_edge/deg_75.csv, figs/projections/chest/mask_edge/deg_255.csv
# [078 & 258] kept 63526/65536 (96.93%) -> figs/projections/chest/mask_edge/deg_78.csv, figs/projections/chest/mask_edge/deg_258.csv
# [081 & 261] kept 63333/65536 (96.64%) -> figs/projections/chest/mask_edge/deg_81.csv, figs/projections/chest/mask_edge/deg_261.csv
# [084 & 264] kept 63153/65536 (96.36%) -> figs/projections/chest/mask_edge/deg_84.csv, figs/projections/chest/mask_edge/deg_264.csv
# [087 & 267] kept 62947/65536 (96.05%) -> figs/projections/chest/mask_edge/deg_87.csv, figs/projections/chest/mask_edge/deg_267.csv
# [090 & 270] kept 62297/65536 (95.06%) -> figs/projections/chest/mask_edge/deg_90.csv, figs/projections/chest/mask_edge/deg_270.csv
# [093 & 273] kept 63054/65536 (96.21%) -> figs/projections/chest/mask_edge/deg_93.csv, figs/projections/chest/mask_edge/deg_273.csv
# [096 & 276] kept 62988/65536 (96.11%) -> figs/projections/chest/mask_edge/deg_96.csv, figs/projections/chest/mask_edge/deg_276.csv
# [099 & 279] kept 63222/65536 (96.47%) -> figs/projections/chest/mask_edge/deg_99.csv, figs/projections/chest/mask_edge/deg_279.csv
# [102 & 282] kept 63304/65536 (96.59%) -> figs/projections/chest/mask_edge/deg_102.csv, figs/projections/chest/mask_edge/deg_282.csv
# [105 & 285] kept 63182/65536 (96.41%) -> figs/projections/chest/mask_edge/deg_105.csv, figs/projections/chest/mask_edge/deg_285.csv
# [108 & 288] kept 63075/65536 (96.24%) -> figs/projections/chest/mask_edge/deg_108.csv, figs/projections/chest/mask_edge/deg_288.csv
# [111 & 291] kept 63038/65536 (96.19%) -> figs/projections/chest/mask_edge/deg_111.csv, figs/projections/chest/mask_edge/deg_291.csv
# [114 & 294] kept 63228/65536 (96.48%) -> figs/projections/chest/mask_edge/deg_114.csv, figs/projections/chest/mask_edge/deg_294.csv
# [117 & 297] kept 63769/65536 (97.30%) -> figs/projections/chest/mask_edge/deg_117.csv, figs/projections/chest/mask_edge/deg_297.csv
# [120 & 300] kept 63786/65536 (97.33%) -> figs/projections/chest/mask_edge/deg_120.csv, figs/projections/chest/mask_edge/deg_300.csv
# [123 & 303] kept 64164/65536 (97.91%) -> figs/projections/chest/mask_edge/deg_123.csv, figs/projections/chest/mask_edge/deg_303.csv
# [126 & 306] kept 64181/65536 (97.93%) -> figs/projections/chest/mask_edge/deg_126.csv, figs/projections/chest/mask_edge/deg_306.csv
# [129 & 309] kept 64292/65536 (98.10%) -> figs/projections/chest/mask_edge/deg_129.csv, figs/projections/chest/mask_edge/deg_309.csv
# [132 & 312] kept 64063/65536 (97.75%) -> figs/projections/chest/mask_edge/deg_132.csv, figs/projections/chest/mask_edge/deg_312.csv
# [135 & 315] kept 64024/65536 (97.69%) -> figs/projections/chest/mask_edge/deg_135.csv, figs/projections/chest/mask_edge/deg_315.csv
# [138 & 318] kept 64283/65536 (98.09%) -> figs/projections/chest/mask_edge/deg_138.csv, figs/projections/chest/mask_edge/deg_318.csv
# [141 & 321] kept 64350/65536 (98.19%) -> figs/projections/chest/mask_edge/deg_141.csv, figs/projections/chest/mask_edge/deg_321.csv
# [144 & 324] kept 64362/65536 (98.21%) -> figs/projections/chest/mask_edge/deg_144.csv, figs/projections/chest/mask_edge/deg_324.csv
# [147 & 327] kept 64486/65536 (98.40%) -> figs/projections/chest/mask_edge/deg_147.csv, figs/projections/chest/mask_edge/deg_327.csv
# [150 & 330] kept 64495/65536 (98.41%) -> figs/projections/chest/mask_edge/deg_150.csv, figs/projections/chest/mask_edge/deg_330.csv
# [153 & 333] kept 64806/65536 (98.89%) -> figs/projections/chest/mask_edge/deg_153.csv, figs/projections/chest/mask_edge/deg_333.csv
# [156 & 336] kept 64803/65536 (98.88%) -> figs/projections/chest/mask_edge/deg_156.csv, figs/projections/chest/mask_edge/deg_336.csv
# [159 & 339] kept 64776/65536 (98.84%) -> figs/projections/chest/mask_edge/deg_159.csv, figs/projections/chest/mask_edge/deg_339.csv
# [162 & 342] kept 64789/65536 (98.86%) -> figs/projections/chest/mask_edge/deg_162.csv, figs/projections/chest/mask_edge/deg_342.csv
# [165 & 345] kept 64709/65536 (98.74%) -> figs/projections/chest/mask_edge/deg_165.csv, figs/projections/chest/mask_edge/deg_345.csv
# [168 & 348] kept 64696/65536 (98.72%) -> figs/projections/chest/mask_edge/deg_168.csv, figs/projections/chest/mask_edge/deg_348.csv
# [171 & 351] kept 64816/65536 (98.90%) -> figs/projections/chest/mask_edge/deg_171.csv, figs/projections/chest/mask_edge/deg_351.csv
# [174 & 354] kept 64211/65536 (97.98%) -> figs/projections/chest/mask_edge/deg_174.csv, figs/projections/chest/mask_edge/deg_354.csv
# [177 & 357] kept 63656/65536 (97.13%) -> figs/projections/chest/mask_edge/deg_177.csv, figs/projections/chest/mask_edge/deg_357.csv
# ✅ Pairwise-union masks (with +180° flip alignment) generated for all available angle pairs, using edge-based masking if configured.
#
# 📊 average mask rate: 2.21% (save to figs/projections/chest/mask_edge/mask_rates_summary.csv)
