# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt

# 输入/输出目录
input_dir = "figs/projections/chest/csv"
output_dir = "figs/projections/chest/projections"

os.makedirs(output_dir, exist_ok=True)

# 找到所有 deg_*.csv
csv_files = glob.glob(os.path.join(input_dir, "deg_*.csv"))

for csv_file in csv_files:
    # 读取 CSV
    data = pd.read_csv(csv_file, header=None).to_numpy()
    
    # 生成输出文件名
    base = os.path.basename(csv_file)       # deg_xx.csv
    name = os.path.splitext(base)[0] + ".png"  # deg_xx.png
    out_path = os.path.join(output_dir, name)

    # 保存为灰度图
    plt.imsave(out_path, data, cmap="gray")
    # print(f"Saved {out_path}")

print("✅ All CSV files converted to PNG.")
# Out:
# ✅ All CSV files converted to PNG.

# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


def to_uint8_gray(img):
    """
    将 plt.imread 得到的图像统一转换为灰度 uint8:
    - 若是浮点，范围通常在[0,1]，先缩放到[0,255]
    - 若是 RGB/RGBA，去掉 alpha 并对通道取均值得到灰度
    """
    arr = img
    # 去 alpha 通道
    if arr.ndim == 3 and arr.shape[2] == 4:
        arr = arr[:, :, :3]
    # 转灰度
    if arr.ndim == 3 and arr.shape[2] == 3:
        # 若是float，先不缩放，先转灰度，最后统一缩放到 uint8
        if np.issubdtype(arr.dtype, np.floating):
            gray = arr.mean(axis=2)  # [0,1]
            gray = np.clip(gray * 255.0, 0, 255).astype(np.uint8)
        else:
            # 整型/uint8 直接均值
            gray = arr.mean(axis=2).round().astype(np.uint8)
    elif arr.ndim == 2:
        # 已是灰度
        if np.issubdtype(arr.dtype, np.floating):
            gray = np.clip(arr * 255.0, 0, 255).astype(np.uint8)
        else:
            gray = arr.astype(np.uint8)
    else:
        raise ValueError(f"Unsupported image shape: {arr.shape}")
    return gray


# 输入/输出目录
input_dir = "figs/projections/chest/projections"
output_dir = "figs/projections/chest/mask"
os.makedirs(output_dir, exist_ok=True)

# 找到所有 deg_*.png
png_files = glob.glob(os.path.join(input_dir, "deg_*.png"))

for png_file in png_files:
    # 读取并统一到灰度 uint8
    img = plt.imread(png_file)
    gray = to_uint8_gray(img)

    # 生成 mask：像素为 0 或 255 -> 0，其它 -> 1
    mask = np.where((gray == 0) | (gray == 255), 0, 1).astype(np.uint8)

    # 保存为 CSV（与输入同名）
    base = os.path.basename(png_file)             # deg_xx.png
    name = os.path.splitext(base)[0] + ".csv"     # deg_xx.csv
    out_path = os.path.join(output_dir, name)
    pd.DataFrame(mask).to_csv(out_path, index=False, header=False)

    print(f"Saved mask {out_path}")

print("✅ All mask CSV files generated.")

# %%
import os
import re
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ---------------------------
# Utilities
# ---------------------------
def to_uint8_gray(img):
    """统一转灰度 uint8"""
    arr = img
    if arr.ndim == 3 and arr.shape[2] == 4:  # RGBA -> RGB
        arr = arr[:, :, :3]
    if arr.ndim == 3 and arr.shape[2] == 3:
        if np.issubdtype(arr.dtype, np.floating):
            gray = arr.mean(axis=2)           # [0,1]
            gray = np.clip(gray * 255.0, 0, 255).astype(np.uint8)
        else:
            gray = arr.mean(axis=2).round().astype(np.uint8)
    elif arr.ndim == 2:
        if np.issubdtype(arr.dtype, np.floating):
            gray = np.clip(arr * 255.0, 0, 255).astype(np.uint8)
        else:
            gray = arr.astype(np.uint8)
    else:
        raise ValueError(f"Unsupported image shape: {arr.shape}")
    return gray

def build_initial_mask(gray, mode="threshold", low_ratio=0.00, high_ratio=0.95):
    """
    生成单张图的初始 mask:
    - mode="threshold": 仅保留 [low_ratio, high_ratio] 的像素为 1（其余 0）
    - mode="extreme":   将灰度==0 或 255 的像素置 0，其余 1
    """
    if mode == "threshold":
        low  = int(255 * low_ratio)
        high = int(255 * high_ratio)
        mask = np.where((gray >= low) & (gray <= high), 1, 0).astype(np.uint8)
    elif mode == "extreme":
        mask = np.where((gray == 0) | (gray == 255), 0, 1).astype(np.uint8)
    else:
        raise ValueError("mode must be 'threshold' or 'extreme'")
    return mask

def angle_from_filename(path):
    """从 'deg_XXX.png' 中解析角度整数"""
    m = re.search(r"deg_(\d+)\.png$", os.path.basename(path))
    if not m:
        raise ValueError(f"Bad filename: {path}")
    return int(m.group(1)) % 360

# ---------------------------
# Config
# ---------------------------
input_dir  = "figs/projections/chest/projections"
output_dir = "figs/projections/chest/mask"
os.makedirs(output_dir, exist_ok=True)

MASK_MODE   = "threshold"  # 'threshold' or 'extreme'
LOW_RATIO   = 0.05         # 如需同时屏蔽极暗可设 0.05
HIGH_RATIO  = 0.95         # 屏蔽高亮边缘/伪影

# ---------------------------
# Collect files by angle
# ---------------------------
paths = glob.glob(os.path.join(input_dir, "deg_*.png"))
by_angle = {}
for p in paths:
    ang = angle_from_filename(p)
    by_angle[ang] = p

# ---------------------------
# Process pairs (ang, ang+180)
# ---------------------------
mask_rates = []
visited = set()
for ang in sorted(by_angle.keys()):
    if ang in visited:
        continue
    mate = (ang + 180) % 360
    if mate not in by_angle:
        print(f"Skip angle {ang}: pair {mate} not found.")
        continue

    # 读取两张图并做初始 mask
    img_a = plt.imread(by_angle[ang])
    img_b = plt.imread(by_angle[mate])
    gray_a = to_uint8_gray(img_a)
    gray_b = to_uint8_gray(img_b)

    mask_a0 = build_initial_mask(gray_a, mode=MASK_MODE, low_ratio=LOW_RATIO, high_ratio=HIGH_RATIO)
    mask_b0 = build_initial_mask(gray_b, mode=MASK_MODE, low_ratio=LOW_RATIO, high_ratio=HIGH_RATIO)

    # 关键改动：将 +180° 的初始 mask 水平翻转，使其对齐到 θ 的坐标系
    mask_b0_aligned = np.fliplr(mask_b0)

    # 交集（同一有效像素区域）：θ 坐标系
    # intersect_mask_theta = (mask_a0 & mask_b0_aligned).astype(np.uint8)
    intersect_mask_theta = (mask_a0 | mask_b0_aligned).astype(np.uint8)

    # 保存：θ 用 θ 坐标的交集；θ+180° 用“翻回去”的交集（保持各自原生坐标）
    out_a = os.path.join(output_dir, os.path.splitext(os.path.basename(by_angle[ang]))[0]   + ".csv")
    out_b = os.path.join(output_dir, os.path.splitext(os.path.basename(by_angle[mate]))[0] + ".csv")

    pd.DataFrame(intersect_mask_theta).to_csv(out_a, index=False, header=False)
    pd.DataFrame(np.fliplr(intersect_mask_theta)).to_csv(out_b, index=False, header=False)

    kept = int(intersect_mask_theta.sum())
    total = intersect_mask_theta.size
    print(f"[{ang:03d} & {mate:03d}] kept {kept}/{total} ({kept/total:.2%}) -> {out_a}, {out_b}")
    
    mask_rates.append({
    "angle": ang,
    "mate": mate,
    "kept": kept,
    "total": total,
    "mask_rate": kept / total
    })

    visited.add(ang)
    visited.add(mate)

print("✅ Pairwise-intersection masks (with +180° flip alignment) generated for all available angle pairs.")

df_rates = pd.DataFrame(mask_rates)
out_summary = os.path.join(output_dir, "mask_rates_summary.csv")
df_rates.to_csv(out_summary, index=False)

avg_rate = df_rates["mask_rate"].mean()

print(f"\n📊 average mask rate: {1-avg_rate:.2%} (save to {out_summary})")
# Out:
# [000 & 180] kept 54538/65536 (83.22%) -> figs/projections/chest/mask/deg_00.csv, figs/projections/chest/mask/deg_180.csv
# [003 & 183] kept 57812/65536 (88.21%) -> figs/projections/chest/mask/deg_03.csv, figs/projections/chest/mask/deg_183.csv
# [006 & 186] kept 59746/65536 (91.17%) -> figs/projections/chest/mask/deg_06.csv, figs/projections/chest/mask/deg_186.csv
# [009 & 189] kept 60361/65536 (92.10%) -> figs/projections/chest/mask/deg_09.csv, figs/projections/chest/mask/deg_189.csv
# [012 & 192] kept 61074/65536 (93.19%) -> figs/projections/chest/mask/deg_12.csv, figs/projections/chest/mask/deg_192.csv
# [015 & 195] kept 61709/65536 (94.16%) -> figs/projections/chest/mask/deg_15.csv, figs/projections/chest/mask/deg_195.csv
# [018 & 198] kept 62767/65536 (95.77%) -> figs/projections/chest/mask/deg_18.csv, figs/projections/chest/mask/deg_198.csv
# [021 & 201] kept 64228/65536 (98.00%) -> figs/projections/chest/mask/deg_21.csv, figs/projections/chest/mask/deg_201.csv
# [024 & 204] kept 65149/65536 (99.41%) -> figs/projections/chest/mask/deg_24.csv, figs/projections/chest/mask/deg_204.csv
# [027 & 207] kept 65493/65536 (99.93%) -> figs/projections/chest/mask/deg_27.csv, figs/projections/chest/mask/deg_207.csv
# [030 & 210] kept 65536/65536 (100.00%) -> figs/projections/chest/mask/deg_30.csv, figs/projections/chest/mask/deg_210.csv
# [033 & 213] kept 65536/65536 (100.00%) -> figs/projections/chest/mask/deg_33.csv, figs/projections/chest/mask/deg_213.csv
# [036 & 216] kept 65536/65536 (100.00%) -> figs/projections/chest/mask/deg_36.csv, figs/projections/chest/mask/deg_216.csv
# [039 & 219] kept 65169/65536 (99.44%) -> figs/projections/chest/mask/deg_39.csv, figs/projections/chest/mask/deg_219.csv
# [042 & 222] kept 64525/65536 (98.46%) -> figs/projections/chest/mask/deg_42.csv, figs/projections/chest/mask/deg_222.csv
# [045 & 225] kept 64808/65536 (98.89%) -> figs/projections/chest/mask/deg_45.csv, figs/projections/chest/mask/deg_225.csv
# [048 & 228] kept 65088/65536 (99.32%) -> figs/projections/chest/mask/deg_48.csv, figs/projections/chest/mask/deg_228.csv
# [051 & 231] kept 65536/65536 (100.00%) -> figs/projections/chest/mask/deg_51.csv, figs/projections/chest/mask/deg_231.csv
# [054 & 234] kept 65536/65536 (100.00%) -> figs/projections/chest/mask/deg_54.csv, figs/projections/chest/mask/deg_234.csv
# [057 & 237] kept 65536/65536 (100.00%) -> figs/projections/chest/mask/deg_57.csv, figs/projections/chest/mask/deg_237.csv
# [060 & 240] kept 65520/65536 (99.98%) -> figs/projections/chest/mask/deg_60.csv, figs/projections/chest/mask/deg_240.csv
# [063 & 243] kept 65536/65536 (100.00%) -> figs/projections/chest/mask/deg_63.csv, figs/projections/chest/mask/deg_243.csv
# [066 & 246] kept 65536/65536 (100.00%) -> figs/projections/chest/mask/deg_66.csv, figs/projections/chest/mask/deg_246.csv
# [069 & 249] kept 65506/65536 (99.95%) -> figs/projections/chest/mask/deg_69.csv, figs/projections/chest/mask/deg_249.csv
# [072 & 252] kept 65094/65536 (99.33%) -> figs/projections/chest/mask/deg_72.csv, figs/projections/chest/mask/deg_252.csv
# [075 & 255] kept 65317/65536 (99.67%) -> figs/projections/chest/mask/deg_75.csv, figs/projections/chest/mask/deg_255.csv
# [078 & 258] kept 65393/65536 (99.78%) -> figs/projections/chest/mask/deg_78.csv, figs/projections/chest/mask/deg_258.csv
# [081 & 261] kept 65405/65536 (99.80%) -> figs/projections/chest/mask/deg_81.csv, figs/projections/chest/mask/deg_261.csv
# [084 & 264] kept 65229/65536 (99.53%) -> figs/projections/chest/mask/deg_84.csv, figs/projections/chest/mask/deg_264.csv
# [087 & 267] kept 65055/65536 (99.27%) -> figs/projections/chest/mask/deg_87.csv, figs/projections/chest/mask/deg_267.csv
# [090 & 270] kept 64665/65536 (98.67%) -> figs/projections/chest/mask/deg_90.csv, figs/projections/chest/mask/deg_270.csv
# [093 & 273] kept 64912/65536 (99.05%) -> figs/projections/chest/mask/deg_93.csv, figs/projections/chest/mask/deg_273.csv
# [096 & 276] kept 64839/65536 (98.94%) -> figs/projections/chest/mask/deg_96.csv, figs/projections/chest/mask/deg_276.csv
# [099 & 279] kept 64810/65536 (98.89%) -> figs/projections/chest/mask/deg_99.csv, figs/projections/chest/mask/deg_279.csv
# [102 & 282] kept 64839/65536 (98.94%) -> figs/projections/chest/mask/deg_102.csv, figs/projections/chest/mask/deg_282.csv
# [105 & 285] kept 64963/65536 (99.13%) -> figs/projections/chest/mask/deg_105.csv, figs/projections/chest/mask/deg_285.csv
# [108 & 288] kept 65049/65536 (99.26%) -> figs/projections/chest/mask/deg_108.csv, figs/projections/chest/mask/deg_288.csv
# [111 & 291] kept 65011/65536 (99.20%) -> figs/projections/chest/mask/deg_111.csv, figs/projections/chest/mask/deg_291.csv
# [114 & 294] kept 65333/65536 (99.69%) -> figs/projections/chest/mask/deg_114.csv, figs/projections/chest/mask/deg_294.csv
# [117 & 297] kept 65531/65536 (99.99%) -> figs/projections/chest/mask/deg_117.csv, figs/projections/chest/mask/deg_297.csv
# [120 & 300] kept 65500/65536 (99.95%) -> figs/projections/chest/mask/deg_120.csv, figs/projections/chest/mask/deg_300.csv
# [123 & 303] kept 65526/65536 (99.98%) -> figs/projections/chest/mask/deg_123.csv, figs/projections/chest/mask/deg_303.csv
# [126 & 306] kept 65536/65536 (100.00%) -> figs/projections/chest/mask/deg_126.csv, figs/projections/chest/mask/deg_306.csv
# [129 & 309] kept 65536/65536 (100.00%) -> figs/projections/chest/mask/deg_129.csv, figs/projections/chest/mask/deg_309.csv
# [132 & 312] kept 64957/65536 (99.12%) -> figs/projections/chest/mask/deg_132.csv, figs/projections/chest/mask/deg_312.csv
# [135 & 315] kept 64866/65536 (98.98%) -> figs/projections/chest/mask/deg_135.csv, figs/projections/chest/mask/deg_315.csv
# [138 & 318] kept 64812/65536 (98.90%) -> figs/projections/chest/mask/deg_138.csv, figs/projections/chest/mask/deg_318.csv
# [141 & 321] kept 64845/65536 (98.95%) -> figs/projections/chest/mask/deg_141.csv, figs/projections/chest/mask/deg_321.csv
# [144 & 324] kept 65536/65536 (100.00%) -> figs/projections/chest/mask/deg_144.csv, figs/projections/chest/mask/deg_324.csv
# [147 & 327] kept 65536/65536 (100.00%) -> figs/projections/chest/mask/deg_147.csv, figs/projections/chest/mask/deg_327.csv
# [150 & 330] kept 65536/65536 (100.00%) -> figs/projections/chest/mask/deg_150.csv, figs/projections/chest/mask/deg_330.csv
# [153 & 333] kept 65536/65536 (100.00%) -> figs/projections/chest/mask/deg_153.csv, figs/projections/chest/mask/deg_333.csv
# [156 & 336] kept 65513/65536 (99.96%) -> figs/projections/chest/mask/deg_156.csv, figs/projections/chest/mask/deg_336.csv
# [159 & 339] kept 65333/65536 (99.69%) -> figs/projections/chest/mask/deg_159.csv, figs/projections/chest/mask/deg_339.csv
# [162 & 342] kept 64302/65536 (98.12%) -> figs/projections/chest/mask/deg_162.csv, figs/projections/chest/mask/deg_342.csv
# [165 & 345] kept 62415/65536 (95.24%) -> figs/projections/chest/mask/deg_165.csv, figs/projections/chest/mask/deg_345.csv
# [168 & 348] kept 61158/65536 (93.32%) -> figs/projections/chest/mask/deg_168.csv, figs/projections/chest/mask/deg_348.csv
# [171 & 351] kept 60219/65536 (91.89%) -> figs/projections/chest/mask/deg_171.csv, figs/projections/chest/mask/deg_351.csv
# [174 & 354] kept 59592/65536 (90.93%) -> figs/projections/chest/mask/deg_174.csv, figs/projections/chest/mask/deg_354.csv
# [177 & 357] kept 58061/65536 (88.59%) -> figs/projections/chest/mask/deg_177.csv, figs/projections/chest/mask/deg_357.csv
# ✅ Pairwise-intersection masks (with +180° flip alignment) generated for all available angle pairs.
#
# 📊 average mask rate: 2.10% (save to figs/projections/chest/mask/mask_rates_summary.csv)
